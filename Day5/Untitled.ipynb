# %% [markdown]
# ### Basic Data Types

# %% [markdown]
# ### Integers & Floats

# %%
x = 10

# %%
x
# Out:
# 10

# %%
x = 1.2

# %%
x
# Out:
# 1.2

# %% [markdown]
# #### In C and C++ and Java

# %% [raw]
# int a = 5

# %% [raw]
# float b = 1.2

# %% [markdown]
# ### Type check

# %%
x = 10

# %%
type(x) # It gives type of data
# Out:
# int

# %%
x = 1.2

# %%
type(x)
# Out:
# float

# %%
y = 3.0

# %%
type(y)
# Out:
# float

# %%
y = 3

# %%
type(y)
# Out:
# int

# %% [markdown]
# ### Complex Number

# %%
z = 5 + 3j

# %%
z
# Out:
# (5+3j)

# %%
type(z)
# Out:
# complex

# %% [markdown]
# ### Boolean

# %%
 a = True

# %%
b = False

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %% [markdown]
# ### String

# %%
name = "Samarth"

# %%
name
# Out:
# 'Samarth'

# %%
name = 'Samarth'

# %%
name
# Out:
# 'Samarth'
