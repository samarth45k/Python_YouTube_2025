# %% [markdown]
# ### Arithmetic Operators

# %%
1+2
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*3
# Out:
# 6

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
2**3
# Out:
# 8

# %% [markdown]
# ### Comparison Operators

# %%
5 == 5
# Out:
# True

# %%
5 == 10
# Out:
# False

# %%
5 != 10
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
 1 < 3
# Out:
# True

# %%
3 < 1
# Out:
# False

# %%
10 > 1
# Out:
# True

# %%
1 > 10
# Out:
# False

# %% [markdown]
# ### Less Than Equal To. <=

# %%
7 <= 7
# Out:
# True

# %%
7 <= 5
# Out:
# False

# %% [markdown]
# ### Greater Than Eaual To >=

# %%
7 >= 7
# Out:
# True

# %%
1 >= 7
# Out:
# False

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# #### and

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %% [markdown]
# #### or

# %%
False or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False and False
# Out:
# False

# %% [markdown]
# #### not

# %%
not False
# Out:
# True

# %%
not(False)
# Out:
# True

# %%
not(True)
# Out:
# False

# %%
not True
# Out:
# False

# %% [markdown]
# ### Bitwise

# %%
5 & 3
# Out:
# 1

# %%
5 | 3
# Out:
# 7

# %%
5 ^ 3
# Out:
# 6

# %%
5 << 1
# Out:
# 10

# %%
5 >> 1
# Out:
# 2

# %%
~5
# Out:
# -6

# %%
~5
# Out:
# -6
