# %%
a = input()
# Out:
#  45

# %%
a
# Out:
# '45'

# %%
b = input()
# Out:
#  341276543721345

# %%
b
# Out:
# '341276543721345'

# %%
c = input()
# Out:
#  Samarth

# %%
c
# Out:
# 'Samarth'

# %%
d = input()
# Out:
#  1.2

# %%
d
# Out:
# '1.2'

# %% [markdown]
# ### Input with message

# %%
ammount = input("Enter your ammount :")
# Out:
# Enter your ammount : 1000

# %%
ammount
# Out:
# '1000'

# %%
pin = input("Enter your pin")
# Out:
# Enter your pin 3131

# %%
pin
# Out:
# '3131'

# %% [markdown]
# ### Convert input into integer

# %%
a = input("Enter a number")
# Out:
# Enter a number 45

# %%
a
# Out:
# '45'

# %%
type(a)
# Out:
# str

# %%
number = int(a)

# %%
number
# Out:
# 45

# %%
type(number)
# Out:
# int

# %% [markdown]
# ### Conver input to floating number (1.2)

# %%
a = input("Enter a number")
# Out:
# Enter a number 4.5

# %%
a
# Out:
# '4.5'

# %%
type(a)
# Out:
# str

# %%
decimalNumber = float(a)

# %%
decimalNumber
# Out:
# 4.5

# %%
type(decimalNumber)
# Out:
# float

# %% [markdown]
# ### Errors

# %%
a = input()
# Out:
#  4.5yajfdgashjgf

# %%
a
# Out:
# '4.5yajfdgashjgf'

# %%
number = int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 number = int(a)
#
# ValueError: invalid literal for int() with base 10: '4.5yajfdgashjgf'

# %%
a = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 a = true
#
# NameError: name 'true' is not defined

# %%
a = True

# %% [markdown]
# ### Convert Into Boolean

# %%
a = input("Please enter a boolean value (True or False)")
# Out:
# Please enter a boolean value (True or False) False

# %%
a
# Out:
# 'False'

# %%
type(a)
# Out:
# str

# %%
booleanValue = bool(a)

# %%
booleanValue
# Out:
# True

# %%
a = input("Please enter a boolean value (True or False)")
# Out:
# Please enter a boolean value (True or False)

# %%
a
# Out:
# ''

# %%
booleanValue = bool(a)

# %%
booleanValue
# Out:
# False

# %% [markdown]
# ### F String

# %%
age = 25
name = "Samarth"

# %%
print(f"My age is {age} and my name is {name}")
# Out:
# My age is 25 and my name is Samarth

# %%
name = "Vaibhav" #database

# %%
print(f"Welcome {name}, Please enter your PIN")
# Out:
# Welcome Vaibhav, Please enter your PIN

# %%
# Calculations
x = 20
y = 30
print(f"Addition of {x} and {y} is {x+y}")
# Out:
# Addition of 20 and 30 is 50
