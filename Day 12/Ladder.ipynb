# %%
age = input("Enter your age")
age = int(age)


if age<15:
    print("60% Discount")
    
elif age< 25:
    print("45% Discount")

elif age < 40:
    print("30% Discount")

else:
    print("10% Discount")
# Out:
# Enter your age 31
# 30% Discount

# %%
age = int(input("Enter your age"))
# Out:
# Enter your age 45

# %%
age
# Out:
# 45

# %%
type(age)
# Out:
# int
