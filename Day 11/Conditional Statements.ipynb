# %%
age = input("Enter your age")
# Out:
# Enter your age 25

# %%
age
# Out:
# '25'

# %%
age = int(age)

# %%
age
# Out:
# 25

# %%
age>18
# Out:
# True

# %%
if age>18 : 
    #123
    #123
    #123
    #123
else :
    #456
    #456
    #456
    #456

# %%
if age>18 :    #25 > 18
    print("You can put a vote")
else :
    print("You can not vote")
# Out:
# You can put a vote

# %%
age = 16
if age>18 :    #16 > 18 - False
    print("You can put a vote")
    print("You can put a vote")
    print("You can put a vote")
    print("You can put a vote")
else :
    print("You can not vote")
# Out:
# You can not vote

# %%
age = 20
if age>18 :    #20 > 18 - True
    print("You can put a vote")
else :
    print("You can not vote")
# Out:
# You can put a vote

# %%
age = 18
if age>18 :    #18 > 18 - Flase
    print("You can put a vote")
else :
    print("You can not vote")
# Out:
# You can not vote
