# %% [markdown]
# # Case 1

# %%
s = "Samarth"

# %%
s
# Out:
# 'Samarth'

# %%
s = "Kulkarni"

# %%
s
# Out:
# 'Kulkarni'

# %%
s
# Out:
# 'Kulkarni'

# %%
s
# Out:
# 'Kulkarni'

# %%
s
# Out:
# 'Kulkarni'

# %%
s

# %% [markdown]
# # Case 2

# %%
s = "Samarth"

# %%
s
# Out:
# 'Samarth'

# %%
k = s # now s and k will point to same string "Samarth"

# %%
k
# Out:
# 'Samarth'

# %%
s
# Out:
# 'Samarth'

# %%
k
# Out:
# 'Samarth'

# %%
s
# Out:
# 'Samarth'

# %% [markdown]
# ### Slicing

# %%
name = "Samarth"

# %%
name
# Out:
# 'Samarth'

# %%
name[2:4] #"mar". here 2 --> 3. (4-1)
# Out:
# 'ma'

# %%
# i want mart
name[2:5]. # here 2 ---> 4 (5-1)
# Out:
# 'mar'

# %%
# i wanr marth
name[2:6]. # here 2 ---> 5. (6-1)
# Out:
# 'mart'

# %% [raw]
# Starting Index Is Inclusive ( It considers given starting idex)
# Ending Index is Exclusive ( It considers given ending index - 1)

# %%
# I wanr 'mar'
name = "Samarth"

# %%
name
# Out:
# 'Samarth'

# %%
name[2:5]
# Out:
# 'mar'

# %%
# This is string slicing

# %% [markdown]
# ### JUMP in Slicing

# %%
# stringName[start:end:jump].  jump has default value as 1

# %%
name = "Samarth"

# %%
name
# Out:
# 'Samarth'

# %%
# start : 1 end : 6 jump : 2
name[1:6:2]
# Out:
# 'aat'

# %%
name
# Out:
# 'Samarth'

# %%
# Orignal string remains same as strings are immutable

# %%
name2 = name[1:6:2]

# %%
name2
# Out:
# 'aat'

# %% [markdown]
# ### String Concatenation

# %%
# use +

# %%
"Sam" + "arth"
# Out:
# 'Samarth'

# %%
"Sam" + "arth" + " " + "Kul" + "karni"
# Out:
# 'Samarth Kulkarni'

# %%
"Sam" - "arth"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 "Sam" - "arth"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
2 - 1
# Out:
# 1

# %%
"Sam" / "Kul"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 "Sam" / "Kul"
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
10 / 2
# Out:
# 5.0

# %%
"Sam" * "Kul"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 "Sam" * "Kul"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"Sam" * 3 #shortcut
# Out:
# 'SamSamSam'

# %%
"Sam"+"Sam"+"Sam"
# Out:
# 'SamSamSam'

# %% [markdown]
# ### String Repition

# %%
# u can multiple a string by integer

# %%
"Sam" * 10
# Out:
# 'SamSamSamSamSamSamSamSamSamSam'

# %%
name = 'Samarth'

# %%
name
# Out:
# 'Samarth'

# %%
name*3
# Out:
# 'SamarthSamarthSamarth'

# %%
name
# Out:
# 'Samarth'

# %%
name3 = name* 3

# %%
name3
# Out:
# 'SamarthSamarthSamarth'

# %%
name
# Out:
# 'Samarth'
